# %%
# !pip install selenium

# %%
import selenium
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException , NoSuchElementException
from selenium.webdriver.common.by import By
import time
from selenium import webdriver

# %%
#question 1

# %%
driver = webdriver.Chrome(r"C:\Users\SOOQ ELASER\Desktop\filp robo\chromedriver.exe")

# %%
#save in anaconda file so needs to write only file name
driver = webdriver.Chrome(r"chromedriver.exe")

# %%
driver.get("https://www.naukri.com/")

# %%
designation = driver.find_element(By.CLASS_NAME,"suggestor-input" )
designation.send_keys('Data Analyst')

# %%
location = driver.find_element(By.XPATH,'/html/body/div[1]/div[7]/div/div/div[5]/div/div/div/div[1]/div/input')
location.send_keys('banglore')

# %%
search = driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
job_title = []
job_location = []
company_name = []
experience_required = []

# %%
title_text = driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in title_text[0:10]:
    title = i.text
    job_title.append(title)

location = driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in location[0:10]:
    new_location = i.text
    job_location.append(new_location)
    
    
company_tag = driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]') 
for i in company_tag[0:10]:
    new = i.text
    company_name.append(new)
    
experinece = driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft expwdth"]')   
for i in experinece[0:10]:
    new_e = i.text
    experience_required.append(new_e)

# %%
len(experience_required) , len(company_name)  , len(job_location) , len(job_title)
# Out:
# (10, 10, 10, 10)

# %%
df = pd.DataFrame({'job_title':job_title,'location':job_location,'company_name':company_name,'experience_required':experience_required})
df
# Out:
#                           job_title  \
# 0                      Data Analyst
# 1                      Data Analyst
# 2  Data Analyst - IIT/BITS/Startups
# 3            Data Analyst - FinTech
# 4            Data Analyst - FinTech
# 5            Data Analyst - FinTech
# 6  Data Analyst - IIT/BITS/Startups
# 7                      Data Analyst
# 8              Banking Data Analyst
# 9                      Data Analyst
#
#                                             location  company_name  \
# 0                                Bangalore/Bengaluru           ANZ
# 1                                Bangalore/Bengaluru           ANZ
# 2                                Bangalore/Bengaluru  AVE Promagne
# 3  Mumbai, Hyderabad/Secunderabad, Pune, Ahmedaba...  Primo Hiring
# 4  Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...  Primo Hiring
# 5  Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...  Primo Hiring
# 6                                Bangalore/Bengaluru  AVE Promagne
# ...

# %%
#question 2

# %%
designation = driver.find_element(By.CLASS_NAME,"suggestor-input" )
designation.send_keys('Data Scientist')

# %%
location = driver.find_element(By.XPATH,'//*[@id="root"]/div[6]/div/div/div[5]/div/div/div/div[1]/div/input')
location.send_keys('banglore')

# %%
search = driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
job_title = []
job_location = []
company_name = []

# %%
title_text = driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in title_text[0:10]:
    title = i.text
    job_title.append(title)

location = driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in location[0:10]:
    new_location = i.text
    job_location.append(new_location)
    
    
company_tag = driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]') 
for i in company_tag[0:10]:
    new = i.text
    company_name.append(new)

# %%
len(company_name)  , len(job_location) , len(job_title)
# Out:
# (10, 10, 10)

# %%
df = pd.DataFrame({'job_title':job_title,'location':job_location,'company_name':company_name})
df
# Out:
#                                            job_title  \
# 0                            Data Science Specialist
# 1                                 Data Scientist_NLP
# 2                    Machine Learning (AI) Architect
# 3                               Data Science Analyst
# 4                                     Data Scientist
# 5                          Data Scientist- Bangalore
# 6                Data Science Analyst - Data Science
# 7                  Data Science Analyst Data Science
# 8  Analytics Specialist - Artificial Intelligence...
# 9                              Senior Data Scientist
#
#                                             location       company_name
# 0  Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...          Accenture
# 1  Mumbai, Pune, Chennai, Gurgaon/Gurugram, Banga...  Fractal Analytics
# 2  Kolkata, Mumbai, New Delhi, Hyderabad/Secunder...         Persistent
# 3                                Bangalore/Bengaluru          Accenture
# ...

# %%
#question 3

# %%
driver = webdriver.Chrome(r"chromedriver.exe")
driver.get("https://www.naukri.com/")

# %%
designation = driver.find_element(By.CLASS_NAME,"suggestor-input" )
designation.send_keys('Data Scientist')

# %%
search = driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
job_title = []
job_location = []
company_name = []
experience_required = []

# %%
title_text = driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in title_text[0:10]:
    title = i.text
    job_title.append(title)

location = driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in location[0:10]:
    new_location = i.text
    job_location.append(new_location)
    
    
company_tag = driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]') 
for i in company_tag[0:10]:
    new = i.text
    company_name.append(new)
    
experiance = driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft expwdth"]')
for i in experiance[0:10]:
    required = i.text
    experience_required.append(required)

# %%
len(company_name)  , len(job_location) , len(job_title) , len(experience_required)
# Out:
# (10, 10, 10, 10)

# %%
df = pd.DataFrame({'job_title':job_title,'job_location':job_location,'company_name':company_name,'experience_required':experience_required})
df
# Out:
#                              job_title  \
# 0                Junior Data Scientist
# 1                       Data Scientist
# 2                       Data Scientist
# 3                Junior Data Scientist
# 4       Data Scientist - II (Contract)
# 5                       Data Scientist
# 6  Research Scientist - Bioinformatics
# 7                   Data Scientist - I
# 8            Machine Learning Engineer
# 9   Assistant Manager - Data Scientist
#
#                                         job_location             company_name  \
# 0  Kolkata, Mumbai, New Delhi, Hyderabad/Secunder...                 Analytos
# 1              Gurgaon/Gurugram, Bangalore/Bengaluru                Blackbuck
# 2  Kolkata, Mumbai, New Delhi, Hyderabad/Secunder...                 Analytos
# 3    Gurgaon/Gurugram, United States (USA), Bulgaria                   Adidas
# 4                                   Gurgaon/Gurugram                   Netomi
# ...

# %%
#question 4

# %%
driver = webdriver.Chrome(r"chromedriver.exe")

# %%
driver.get("https://www.flipkart.com/")

# %%
sunglasses = driver.find_element(By.CLASS_NAME,'_3704LK')
sunglasses.send_keys('sunglasses')

# %%
search = driver.find_element(By.CLASS_NAME,"L0Z3Pu")
search.click()

# %%
Brand_name = []
price = []
product_description = []

# %%
start = 0
end = 3

for page in range(start,end):
    name = driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
    for i in name:
        Brand_name.append(i.text)
        
    next_button = driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(3)
    
Brand_name = Brand_name[0:100]
len(Brand_name)
# Out:
# 100

# %%
start = 0
end = 3

for page in range(start,end):
    money = driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
    for i in money:
        price.append(i.text)
        
    next_button = driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(3)
price = price[0:100]
len(price)
# Out:
# 100

# %%
start = 0
end = 3

for page in range(start,end):
    brand = driver.find_elements(By.XPATH,'//a[@class="IRpwTa" or @class="_1a8UBa"]')
    for i in brand:
        product_description.append(i.text)
    
        
    next_button = driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(3)
    
product_description = product_description[0:100]
len(product_description)
# Out:
# 100

# %%
product_description
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2eb676a81f41c5fc4c83f2667c15581a", element="CA70E65B9B9D7E27D90797233D03D781_element_584")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2eb676a81f41c5fc4c83f2667c15581a", element="CA70E65B9B9D7E27D90797233D03D781_element_585")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2eb676a81f41c5fc4c83f2667c15581a", element="CA70E65B9B9D7E27D90797233D03D781_element_586")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2eb676a81f41c5fc4c83f2667c15581a", element="CA70E65B9B9D7E27D90797233D03D781_element_587")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2eb676a81f41c5fc4c83f2667c15581a", element="CA70E65B9B9D7E27D90797233D03D781_element_588")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2eb676a81f41c5fc4c83f2667c15581a", element="CA70E65B9B9D7E27D90797233D03D781_element_589")>,
# ...

# %%
len(Brand_name),len(price),len(product_description)
# Out:
# (100, 100, 100)

# %%
df = pd.DataFrame({'Brand_name':Brand_name,'price':price,'product_description':product_description})
df
# Out:
#        Brand_name price                                product_description
# 0   VINCENT CHASE  ₹125  <selenium.webdriver.remote.webelement.WebEleme...
# 1   VINCENT CHASE  ₹189  <selenium.webdriver.remote.webelement.WebEleme...
# 2          PIRASO  ₹292  <selenium.webdriver.remote.webelement.WebEleme...
# 3          TamTam  ₹789  <selenium.webdriver.remote.webelement.WebEleme...
# 4          PIRASO  ₹873  <selenium.webdriver.remote.webelement.WebEleme...
# ..            ...   ...                                                ...
# 95  VINCENT CHASE  ₹789  <selenium.webdriver.remote.webelement.WebEleme...
# 96         PIRASO  ₹185  <selenium.webdriver.remote.webelement.WebEleme...
# 97       Fastrack  ₹489  <selenium.webdriver.remote.webelement.WebEleme...
# 98         PIRASO  ₹212  <selenium.webdriver.remote.webelement.WebEleme...
# 99  VINCENT CHASE  ₹789  <selenium.webdriver.remote.webelement.WebEleme...
#
# [100 rows x 3 columns]

# %%
#question 5

# %%
driver = webdriver.Chrome(r"C:\Users\SOOQ ELASER\Desktop\filp robo\chromedriver.exe")

# %%
driver.get("https://www.flipkart.com/apple-iphone-11-black-64-gb/product-reviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&market")

# %%
rating = []

review = driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
for i in review:
    feedback = i.text
    rating.append(feedback)
    
review_summary = []

summary = driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
for i in summary:
    feedback = i.text
    review_summary.append(feedback)  
    
full_review = []
full = driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
for i in full:
    review = i.text
    full_review.append(review)

# %%
    
review_summary = []

summary = driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
for i in summary:
    feedback = i.text
    review_summary.append(feedback)  
review_summary
# Out:
# ['Simply awesome',
#  'Perfect product!',
#  'Best in the market!',
#  'Value-for-money',
#  'Highly recommended',
#  'Worth every penny',
#  'Perfect product!',
#  'Pretty good',
#  'Highly recommended',
#  'Great product']

# %%
rating = []
review_summary = []
full_review = []

# %%
start= 0
end =10

for page in range(start,end):
    desc=driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
    for i in desc:
        rating.append(i.text)
        
        
    next_button=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(3)

# %%
start= 0
end =10

for page in range(start,end):
    summary = driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
    for i in summary:
        review_summary.append(i.text)
    
    next_button=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(3)

# %%
start= 0
end =10

for page in range(start,end):
    full = driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
    for i in full:
        full_review.append(i.text)
    
    next_button=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(3)

# %%
len(full_review) , len(rating) ,len(review_summary)
# Out:
# (110, 100, 100)

# %%
full_review = full_review[:100]
full_review


rating = rating[:100]
rating

review_summary=review_summary[:100]
review_summary
# Out:
# ['Fabulous!',
#  'Classy product',
#  'Worth every penny',
#  'Perfect product!',
#  'Good choice',
#  'Perfect product!',
#  'Highly recommended',
#  'Highly recommended',
#  'Perfect product!',
#  'Value-for-money',
#  'Simply awesome',
#  'Perfect product!',
#  'Best in the market!',
#  'Value-for-money',
#  'Highly recommended',
#  'Worth every penny',
#  'Perfect product!',
#  'Pretty good',
#  'Highly recommended',
#  'Great product',
#  'Simply awesome',
#  'Perfect product!',
#  'Best in the market!',
#  'Value-for-money',
#  'Highly recommended',
#  'Worth every penny',
#  'Perfect product!',
#  'Pretty good',
#  'Highly recommended',
#  'Great product',
#  'Fabulous!',
#  'Classy product',
#  'Worth every penny',
#  'Perfect product!',
#  'Good choice',
#  'Perfect product!',
#  'Highly recommended',
#  'Highly recommended',
#  'Perfect product!',
#  'Value-for-money',
#  'Fabulous!',
#  'Classy product',
#  'Worth every penny',
#  'Perfect product!',
#  'Good choice',
# ...

# %%
len(full_review) , len(rating) ,len(review_summary)
# Out:
# (100, 100, 100)

# %%
df = pd.DataFrame({'rating':rating,'review_summary':review_summary , 'full_review': full_review})
df
# Out:
#    rating      review_summary  \
# 0       5           Fabulous!
# 1       5      Classy product
# 2       5   Worth every penny
# 3       4    Perfect product!
# 4       5         Good choice
# ..    ...                 ...
# 95      5   Worth every penny
# 96      5    Perfect product!
# 97      4         Pretty good
# 98      5  Highly recommended
# 99      5       Great product
#
#                                           full_review
# 0   This is my first iOS phone. I am very happy wi...
# 1   Best and amazing product.....phone looks so pr...
# 2   i11 is worthy to buy, too much happy with the ...
# 3   It’s a must buy who is looking for an upgrade ...
# 4   So far it’s been an AMAZING experience coming ...
# ..                                                ...
# 95  Value for money❤️❤️\nIts awesome mobile phone ...
# 96  iphone 11 is a very good phone to buy only if ...
# 97  Amazing camera quality as expected, battery al...
# ...

# %%
#question 6

# %%
driver = webdriver.Chrome(r"C:\Users\SOOQ ELASER\Desktop\filp robo\chromedriver.exe")

# %%
driver.get('https://www.flipkart.com/')

# %%
sneakers = driver.find_element(By.CLASS_NAME,'_3704LK')
sneakers.send_keys('sneaker')

# %%
search = driver.find_element(By.CLASS_NAME,"_34RNph")
search.click()

# %%
brand_name = []
description = []
price = []

# %%
start = 0
end=3

for page in range(start,end):
    name = driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
    for i in name:
        brand_name.append(i.text)  
        
    next_button = driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(5)
    

brand_name = brand_name[0:100]
brand_name
# Out:
# ['RapidBox',
#  'aadi',
#  'Layasa',
#  'aadi',
#  'BIRDE',
#  'BIRDE',
#  'Kraasa',
#  'Kraasa',
#  'RINDAS',
#  'Kraasa',
#  'Magnolia',
#  'Sparx',
#  'BIRDE',
#  'BRUTON',
#  'BIRDE',
#  'Labbin',
#  'aadi',
#  'BRUTON',
#  'BRUTON',
#  'Layasa',
#  'BRUTON',
#  'Sparx',
#  'aadi',
#  'HIGHLANDER',
#  'Layasa',
#  'BRUTON',
#  'KNIGHT WALKERS',
#  'aadi',
#  'asian',
#  'aadi',
#  'Kraasa',
#  'PUMA',
#  'asian',
#  'World Wear Footwear',
#  'BIRDE',
#  'BIRDE',
#  'BRUTON',
#  'UMAV',
#  'Shozie',
#  'Shozie',
#  'Dillions',
#  'RapidBox',
#  'BIRDE',
#  'PUMA',
#  'PUMA',
#  'asian',
#  'BRUTON',
#  'RapidBox',
#  'WHITE WALKERS',
#  'SFR',
#  'Shozie',
#  'BRUTON',
#  'asian',
#  'WHITE WALKERS',
#  'PUMA',
#  'World Wear Footwear',
#  'SOLETHREADS',
#  'Kraasa',
#  'BIRDE',
#  'SFR',
#  'BRUTON',
#  'Footox',
#  'Shozie',
#  'BRUTON',
#  'BRUTON',
#  'asian',
#  'BRUTON',
#  'ONECENTRE',
#  'PUMA',
#  'AAKA style',
#  'BRUTON',
#  'PUMA',
#  'asian',
#  'aadi',
# ...

# %%
start = 0
end=3

for page in range(start,end):
    desc=driver.find_elements(By.XPATH,'//a[@class="IRpwTa" ]')#scraping description from the xpath
    for i in desc:
        description.append(i.text)
        
    next_button = driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(3)
    
description = description [0:100]
description
# Out:
# ['Sneakers For Men',
#  'Sneakers For Men',
#  'Casual Shoes Sneakers For Women',
#  'Glory Sneakers For Men',
#  'Puma Wired Cage Sneakers For Men',
#  'Skypy-31 Walking Shoes,Training Shoes,Sneakers,Loafers,...',
#  'Lightweight,Comfort,Summer,Trendy,Walking,Outdoor,Styli...',
#  'Men Combo Pack of 2 Casual & Sneaker Shoes (Loafer Shoe...',
#  'Stylish & Trending Outdoor Walking Comfortable Sneakers...',
#  'Casual Shoes For Men Sneakers For Men',
#  'Classic Sneakers For Men',
#  'Sneakers For Men',
#  'WATERPROOF-05cFULLBLACK Sneakers For Men',
#  'Stylish & Trending Outdoor Walking Comfortable Sneakers...',
#  'UP Sneakers For Men',
#  'Exclusive Affordable Collection of Trendy & Stylish Cas...',
#  'Stylish Walking Partywear Sneakers Casual Shoes Sneaker...',
#  'Sneakers For Women',
#  'Combo Pack of 2 Sports Shoes Sneakers For Men',
#  '2006 Trenddy Fashion Sporty Casuals Sneakers Running Sh...',
#  'Mesh |Lightweight|Comfort|Summer|Trendy|Walking|Outdoor...',
# ...

# %%
start = 0
end=3

for page in range(start,end):
    pric = driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')#scraping description from the xpath
    for i in pric:
        price.append(i.text) 
        
    next_button = driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(3)
    
price = price[0:100]
price
# Out:
# ['₹579',
#  '₹579',
#  '₹323',
#  '₹1,500',
#  '₹1,259',
#  '₹499',
#  '₹299',
#  '₹399',
#  '₹429',
#  '₹479',
#  '₹599',
#  '₹489',
#  '₹599',
#  '₹429',
#  '₹1,999',
#  '₹229',
#  '₹1,099',
#  '₹299',
#  '₹499',
#  '₹295',
#  '₹299',
#  '₹349',
#  '₹445',
#  '₹299',
#  '₹499',
#  '₹509',
#  '₹957',
#  '₹608',
#  '₹1,999',
#  '₹269',
#  '₹399',
#  '₹599',
#  '₹639',
#  '₹349',
#  '₹399',
#  '₹499',
#  '₹4,908',
#  '₹499',
#  '₹499',
#  '₹384',
#  '₹499',
#  '₹517',
#  '₹449',
#  '₹299',
#  '₹499',
#  '₹499',
#  '₹299',
#  '₹579',
#  '₹399',
#  '₹449',
#  '₹499',
#  '₹1,499',
#  '₹499',
#  '₹199',
#  '₹499',
#  '₹379',
#  '₹349',
#  '₹539',
#  '₹249',
#  '₹449',
#  '₹499',
#  '₹1,199',
#  '₹299',
#  '₹497',
#  '₹399',
#  '₹249',
#  '₹399',
#  '₹499',
#  '₹599',
#  '₹349',
#  '₹2,749',
#  '₹1,399',
#  '₹774',
#  '₹279',
#  '₹499',
#  '₹349',
#  '₹1,839',
#  '₹5,499',
#  '₹499',
#  '₹445',
#  '₹499',
#  '₹517',
#  '₹449',
#  '₹299',
#  '₹499',
#  '₹499',
#  '₹299',
#  '₹579',
# ...

# %%
len(price),len(description),len(brand_name)
# Out:
# (100, 100, 100)

# %%
df = pd.DataFrame({'brand_name':brand_name,'description':description,'price':price})
df
# Out:
#    brand_name                                        description   price
# 0    RapidBox                                   Sneakers For Men    ₹579
# 1        aadi                                   Sneakers For Men    ₹579
# 2      Layasa                    Casual Shoes Sneakers For Women    ₹323
# 3        aadi                             Glory Sneakers For Men  ₹1,500
# 4       BIRDE                   Puma Wired Cage Sneakers For Men  ₹1,259
# ..        ...                                                ...     ...
# 95     Labbin  Exclusive Affordable Collection of Trendy & St...    ₹379
# 96     BRUTON  Stylish Walking Partywear Sneakers Casual Shoe...    ₹349
# 97     BRUTON                                 Sneakers For Women    ₹539
# 98     BRUTON      Combo Pack of 2 Sports Shoes Sneakers For Men    ₹249
# 99     Layasa  2006 Trenddy Fashion Sporty Casuals Sneakers R...    ₹449
#
# [100 rows x 3 columns]

# %%
#question 7

# %%
amazon = webdriver.Chrome(r"C:\Users\SOOQ ELASER\Desktop\filp robo\chromedriver.exe")

# %%
amazon.get('https://www.amazon.in/')

# %%
laptop = amazon.find_element(By.ID,'twotabsearchtextbox')
laptop.send_keys('laptop')

# %%
search = amazon.find_element(By.ID,"nav-search-submit-button")
search.click()

# %%
title = []

name = amazon.find_elements(By.XPATH,'//span[@class="a-size-medium a-color-base a-text-normal"]')
for i in name:
    lap = i.text
    title.append(lap)
Price=[]

name = amazon.find_elements(By.XPATH,'//span[@class="a-price-whole"]')
for i in name:
    rate = i.text
    Price.append(rate)

# %%
title =title[:10]
title
# Out:
# ['ASUS TUF Gaming F15 (2022), 15.6"(39.62 cms) FHD 144Hz, Intel Core i7-12700H 12th Gen, RTX 3050 Ti 4GB Graphics, Gaming Laptop (16GB/512GB SSD/90WHrs Battery/Windows 11/Gray/2.2 Kg), FX507ZE-HN038W',
#  'Lenovo ThinkPad E14 Intel Core i7 12th Gen 14" FHD IPS Thin and Light Laptop (16GB RAM/1TB SSD/Windows 11 Home/MS Office H&S 2021/Backlit Keybaord/FPR/Black/1.59 kg), 21E3S05800',
#  'HP Envy x360 12th Gen Intel Core i7-13.3 inch(33.8 cm) OLED Multi-Touch Gorilla Glass 2-in-1 Laptop(16GB RAM/512GB SSD/400 nits/Win 11/Intel Iris Xe Graphics/Alexa/B&O/Zenvo Pen/MSO/1.32Kg)13 bf0059TU',
#  'Samsung Galaxy Book2 (NP750) Intel 12th Gen core i7 39.6cm (15.6") FHD Thin & Light Laptop (16 GB/512 GB/Windows 11/MS Office/Backlit Keyboard/Fingerprint Reader/Silver/1.55Kg), NP750XED-KC2IN',
#  'LG Gram16 Intel EVO-[12th Gen Core i7/Win11/16GB/512GB SSD Intel Iris Xe Graphics] [Thunderbolt4/USB-C] [FHD Webcam+Built-in AI] 80WH Battery 3Yrs Warranty(Black,1.14 Kg)',
# ...

# %%
Price = Price[:10]
Price
# Out:
# ['94,989',
#  '98,990',
#  '1,02,990',
#  '79,990',
#  '99,990',
#  '1,29,990',
#  '79,990',
#  '74,990',
#  '88,990',
#  '84,999']

# %%
len(title),len(Price)
# Out:
# (10, 10)

# %%
df = pd.DataFrame({'title':title,'Price':Price})
df
# Out:
#                                                title     Price
# 0  ASUS TUF Gaming F15 (2022), 15.6"(39.62 cms) F...    94,989
# 1  Lenovo ThinkPad E14 Intel Core i7 12th Gen 14"...    98,990
# 2  HP Envy x360 12th Gen Intel Core i7-13.3 inch(...  1,02,990
# 3  Samsung Galaxy Book2 (NP750) Intel 12th Gen co...    79,990
# 4  LG Gram16 Intel EVO-[12th Gen Core i7/Win11/16...    99,990
# 5  Acer Predator Helios Neo 16 Gaming Laptop 13th...  1,29,990
# 6  HP Victus Gaming Latest 12th Gen Intel Core i7...    79,990
# 7  MSI Modern 14, Intel 13th Gen. i7-1355U, 36CM ...    74,990
# 8  HP Pavilion Plus, 12th Gen Intel Core i7 16GB ...    88,990
# 9  HP Pavilion 14 12th Gen Intel Core i7 16GB SDR...    84,999

# %%
#question 8

# %%
quotes = webdriver.Chrome(r"C:\Users\SOOQ ELASER\Desktop\filp robo\chromedriver.exe")

# %%
quotes.get('https://www.azquotes.com/top_quotes.html')

# %%
Quotes = []
Author = []
Type_Of_Quotes = []

# %%
title = quotes.find_elements(By.XPATH,'//a[@class="title"]')
for i in title:
    Quotes.append(i.text)
    
name = quotes.find_elements(By.XPATH,'//div[@class="author"]') 
for i in name:
    Author.append(i.text)
    
types = quotes.find_elements(By.XPATH,'//div[@class="tags"]') 
for i in types:
    Type_Of_Quotes.append(i.text)

# %%
Quotes = Quotes[:100]
Quotes
# Out:
# ['The essence of strategy is choosing what not to do.',
#  'One cannot and must not try to erase the past merely because it does not fit the present.',
#  'Patriotism means to stand by the country. It does not mean to stand by the president.',
#  'Death is something inevitable. When a man has done what he considers to be his duty to his people and his country, he can rest in peace. I believe I have made that effort and that is, therefore, why I will sleep for the eternity.',
#  'You have to love a nation that celebrates its independence every July 4, not with a parade of guns, tanks, and soldiers who file by the White House in a show of strength and muscle, but with family picnics where kids throw Frisbees, the potato salad gets iffy, and the flies die from happiness. You may think you have overeaten, but it is patriotism.',
# ...

# %%
len(Quotes),len(Author),len(Type_Of_Quotes)
# Out:
# (100, 100, 100)

# %%
df = pd.DataFrame({'Quotes':Quotes,'Author':Author,'Type_Of_Quotes':Type_Of_Quotes})
df
# Out:
#                                                Quotes                Author  \
# 0   The essence of strategy is choosing what not t...        Michael Porter
# 1   One cannot and must not try to erase the past ...            Golda Meir
# 2   Patriotism means to stand by the country. It d...    Theodore Roosevelt
# 3   Death is something inevitable. When a man has ...        Nelson Mandela
# 4   You have to love a nation that celebrates its ...          Erma Bombeck
# ..                                                ...                   ...
# 95     When the going gets weird, the weird turn pro.    Hunter S. Thompson
# 96  When a train goes through a tunnel and it gets...       Corrie Ten Boom
# 97  If you think you are too small to make a diffe...            Dalai Lama
# 98  God doesn't require us to succeed, he only req...         Mother Teresa
# 99    Change your thoughts and you change your world.  Norman Vincent Peale
#
#                               Type_Of_Quotes
# ...

# %%
#question 10

# %%
motor = webdriver.Chrome(r"C:\Users\SOOQ ELASER\Desktop\filp robo\chromedriver.exe")

# %%
motor.get('https://www.motor1.com/features/308149/most-expensive-new-cars-ever/')

# %%
car_name = []

name = motor.find_elements(By.XPATH,'//h3[@class="subheader"]')
for i in name:
    car_name.append(i.text)
      
car_name = car_name[:50]
car_name

description = []


des = motor.find_elements(By.TAG_NAME,'p')
for i in des:
    products = i.text
    description.append(products)
    
description = description[:50]
description
    
    
price = []


describe = motor.find_elements(By.TAG_NAME,'strong')
for i in describe:
    describ = i.text
    price.append(describ)
price = price[:50] 
price
# Out:
# ['Price: $1.3 Million',
#  'Price: $1.4 Million',
#  'Price: $1.4 Million',
#  '',
#  'Price: $1.7 Million',
#  'Price: $1.7 Million',
#  'Price: $1.7 Million',
#  'Price: $1.7 Million',
#  'Price: $1.7 Million',
#  'Price: $1.7 Million',
#  'Price: $1.8 Million',
#  'Price: $1.9 Million',
#  'Price: $1.9 Million',
#  'Price: $2.0 Million',
#  'Price: $2.0 Million',
#  'Price: $2.0 Million*',
#  'Price: $2.1 Million',
#  'Price: $2.3 Million',
#  'Price: $2.3 Million',
#  'Price: $2.3 Million',
#  'Price: $2.4 Million',
#  'Price: $2.5 Million',
#  'Price: $2.5 Million',
#  'Price: $2.6 Million',
#  'Price: $2.6 Million',
#  'Price: $2.6 Million',
#  'Price: $2.7 Million',
#  'Price: $3.0 Million',
#  '$3.0 Million',
#  'Price: $3.0 Million',
#  'Price: $3.2 Million',
#  'Price: $3.4 Million',
#  '$3.5 Million',
#  'Price: $3.5 Million',
#  'Price: $3.6 Million',
#  'Price: $3.6 million',
#  'Price: $3.7 Million',
#  'Price: $3.9 Million',
#  'Price: $4.5 Million',
# ...

# %%
len(car_name) , len(price) , len(description)
# Out:
# (50, 50, 50)

# %%
df = pd.DataFrame({'car_name':car_name,'price':price,'description':description})
df
# Out:
#                            car_name                 price  \
# 0                     De Tomaso P72   Price: $1.3 Million
# 1                 Ferrari LaFerrari   Price: $1.4 Million
# 2                     Pagani Huayra   Price: $1.4 Million
# 3                      McLaren Elva
# 4                       Czinger 21C   Price: $1.7 Million
# 5                     Ferrari Monza   Price: $1.7 Million
# 6                Gordon Murray T.33   Price: $1.7 Million
# 7                 Koenigsegg Gemera   Price: $1.7 Million
# 8                       Zenvo TSR-S   Price: $1.7 Million
# 9                Hennessey Venom F5   Price: $1.7 Million
# 10                  Bentley Bacalar   Price: $1.8 Million
# 11    Hispano Suiza Carmen Boulogne   Price: $1.9 Million
# 12           Bentley Mulliner Batur   Price: $1.9 Million
# 13                     Deus Vayanne   Price: $2.0 Million
# 14                      SSC Tuatara   Price: $2.0 Million
# ...

# %%
#question 9

# %%
driver = webdriver.Chrome(r"C:\Users\SOOQ ELASER\Desktop\filp robo\chromedriver.exe")

# %%
driver.get('https://www.jagranjosh.com/general-knowledge/list-of-all-prime-ministers-of-india-1473165149-1')

# %%
Name = []
names = driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[2]/p')
for name in names:
    Name.append(name.text)
    
BORN_DEAD = []
names = driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[3]/p')
for i in names:
    BORN_DEAD.append(i.text)
    
Term_of_office = []
names = driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[4]/p')
for i in names:
    Term_of_office.append(i.text)

Remark = []
names = driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[5]/p')
for i in names:
    Remark.append(i.text)

# %%
Term_of_office = Term_of_office[0::2]
Term_of_office[0::2]
# Out:
# ['15 August 1947 to 27 May 1964',
#  '9 June 1964 to 11 January 1966',
#  '24 January 1966 to 24 March 1977',
#  '28 July 1979 to 14 January 1980',
#  '31 October 1984 to 2 December 1989',
#  '10 November 1990 to 21 June 1991',
#  '16 May 1996 to 1 June 1996',
#  '21 April 1997 to 19 March 1998 ',
#  '22 May 2004 to 26 May 2014   ']

# %%
len(Remark),len(Term_of_office), len(BORN_DEAD), len(Name)
# Out:
# (18, 18, 18, 18)

# %%
df = pd.DataFrame({'Name':Name,'BORN_DEAD':BORN_DEAD,'Remark':Remark,'Term_of_office':Term_of_office})
df
# Out:
#                            Name     BORN_DEAD  \
# 0             Jawahar Lal Nehru   (1889–1964)
# 1     Gulzarilal Nanda (Acting)   (1898-1998)
# 2           Lal Bahadur Shastri   (1904–1966)
# 3   Gulzari Lal Nanda  (Acting)   (1898-1998)
# 4                 Indira Gandhi   (1917–1984)
# 5                 Morarji Desai   (1896–1995)
# 6                  Charan Singh   (1902–1987)
# 7                 Indira Gandhi   (1917–1984)
# 8                  Rajiv Gandhi   (1944–1991)
# 9                   V. P. Singh   (1931–2008)
# 10              Chandra Shekhar   (1927–2007)
# 11          P. V. Narasimha Rao   (1921–2004)
# 12         Atal Bihari Vajpayee  (1924- 2018)
# 13             H. D. Deve Gowda   (born 1933)
# 14           Inder Kumar Gujral   (1919–2012)
# 15         Atal Bihari Vajpayee   (1924-2018)
# 16               Manmohan Singh   (born 1932)
# 17                Narendra Modi   (born 1950)
#
#                                                Remark  \
# ...
